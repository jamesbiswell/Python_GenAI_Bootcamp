# %% [markdown]
# ## LangChain Tools and ReAct

# %%
pip install -r ./requirements.txt -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Download [requirements.txt](https://drive.google.com/file/d/1DxmberiV7YbuJt_RU0VK3P8qfazUSPH3/view?usp=sharing)

# %%
# authenticating to OpenAI
import os
from dotenv import load_dotenv, find_dotenv

# loading the API Keys from .env
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %% [markdown]
# ### LangChain Tools: DuckDuckGo and Wikipedia

# %% [markdown]
# ### DuckDuckGo Search

# %%
pip install -q duckduckgo-search
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# optional, filter workings (recommended in production)
import warnings
warnings.filterwarnings('ignore', module='langchain')

# %%
from langchain_classic.tools import DuckDuckGoSearchRun

search = DuckDuckGoSearchRun()
output = search.invoke('Where was Michael Jackson born?')
print(output)
# Out:
# Jackson's childhood home in Gary, Indiana, pictured in March 2010 Michael Joseph Jackson [3][4] was born in Gary, Indiana, on August 29, 1958. [5][6] He was the eighth of ten children in the Jackson family, a working-class African-American family living in a two-bedroom house on Jackson Street. [7][8] His mother, Katherine Esther Jackson (née Scruse), played clarinet and piano, had aspired to ... Michael Jackson (born August 29, 1958, Gary, Indiana, U.S.—died June 25, 2009, Los Angeles, California) was an American singer, songwriter, and dancer who was one of the most popular and influential entertainers in the world in the late 20th and early 21st centuries. Michael Jackson, often hailed as the 'King of Pop,' was more than just an iconic American singer, songwriter, and dancer; he was a global phenomenon who reshaped the landscape of music, dance, and popular culture. His influence extended beyond his Michael Jackson-level dance moves and vocals, touching the hearts and souls of millions worldwide. Early Michael Jackson's date of birth (DOB) is August 29, 1958. He was born in Gary, Indiana, USA. Michael Jackson was an American singer, songwriter, and dancer. He is widely regarded as one of the most influential entertainers of all time and is often referred to as the "King of Pop." Michael Jackson's DOB is significant because it marks the beginning of the life of one of the most iconic and ... 01 Michael Jackson was born on August 29, 1958. 02 He died in 2009 at the age of 50. 03 Michael Jackson had three children from his two wives. 04 He made his professional debut in the year 1964 at six years old. 05 Michael Jackson became a dominant figure in popular music by the early 1980s.

# %%
search.name
# Out:
# 'duckduckgo_search'

# %%
search.description
# Out:
# 'A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.'

# %%
from langchain_classic.tools import DuckDuckGoSearchResults
search = DuckDuckGoSearchResults()
output = search.run('Metallica Band.')
print(output)
# Out:
# snippet: Metallica's fifth, self-titled album, often called The Black Album, was released in 1991 and debuted at number one on the Billboard 200. [4] The band embarked on a two-year tour in support of the album. Metallica has since been certified 16 times platinum by the RIAA. [3] Metallica followed with the release of Load and Reload, respectively. [5], title: Metallica discography - Wikipedia, link: https://en.wikipedia.org/wiki/Metallica_discography, snippet: Band Timeline History Music Releases Songs & Lyrics Metallica. Media Videos Photos Podcast Museum Enter the Metallica Black Box Fan Club News So What! Contests ... Though Cliff's time with Metallica was brief, his impact and influence remain monumental through his music, our memories, and stories. EXPLORE THE MUSEUM STORE. MERCH. Met Store ..., title: Metallica.com, link: https://www.metallica.com/?os&ref=app, snippet: Metallica has announced that its "M72" world tour will be extended into a third year, with the announcement of 21 North American shows spanning April, May and June 2025. ... Upcoming Dates Past Dates News News In The Press ...And On Top Of That Band Timeline History Music Releases Songs & Lyrics Metallica. Media Videos Photos Podcast Museum ..., title: Variety: Metallica Announce 2025 Tour Dates, With Pantera, Limp Bizkit ..., link: https://www.metallica.com/news/in-the-press/2024-09-19-in-the-press-02.html, snippet: Metallica's most hated album is far from the complete write-off many would have you believe; Frantic and the title track still go hard, songs like Invisible Kid and cult fan fave Dirty Window could have been world class with more work and the countrified re-dub of All Within My Hands the band have experimented with in recent years shows there ..., title: Every Metallica album ranked from worst to best - Louder, link: https://www.loudersound.com/features/metallicas-albums-ranked-worst-to-best

# %%
from langchain_community.utilities import DuckDuckGoSearchAPIWrapper

wrapper = DuckDuckGoSearchAPIWrapper(region='de-de', max_results=3, safesearch='moderate')
search = DuckDuckGoSearchResults(api_wrapper=wrapper)
output = search.run('Hamburg')

# %%
print(output)
# Out:
# snippet: Hamburg ([ˈhambʊʁk] ; regiolektal auch [ˈhambʊɪ̯ç] , dialektal [ˈhambɔʁχ]), amtlich Freie und Hansestadt Hamburg (niederdeutsch Friee un Hansestadt Hamborg, Ländercode HH), ist als Stadtstaat ein Land der Bundesrepublik Deutschland., title: Hamburg - Wikipedia, link: https://de.wikipedia.org/wiki/Hamburg, snippet: In Hamburg wird am 2. März gewählt. Der Wahl-O-Mat der Bundeszentrale für politische Bildung fragt Positionen der Nutzer ab und vergleicht sie mit den Profilen der Parteien. 1,3 Millionen ..., title: Wahl-O-Mat zur Wahl in Hamburg: Welche Partei passt zu mir?, link: https://www.zdf.de/nachrichten/politik/deutschland/wahlomat-hamburg-buergerschaftswahl-2025-100.html, snippet: Von der Elbphilharmonie über die Reeperbahn bis zum Miniatur Wunderland: Die besten Hamburg-Sehenswürdigkeiten 2024 mit Karte., title: Top 12 Sehenswürdigkeiten in Hamburg 2025: Karte und Geheimtipps - ADAC, link: https://www.adac.de/reise-freizeit/reiseplanung/inspirationen/deutschland/hamburg-sehenswuerdigkeiten/, snippet: Hamburg Geheimtipps für alle, die Hamburg wie ein Einheimischer entdecken möchten. Jede Menge coole Spots in allen Ecken der Hansestadt., title: 33 Hamburg Geheimtipps, die nur Einheimische kennen - Travel-Du.de, link: https://travel-du.de/14535/hamburg-geheimtipps/

# %%
import re

pattern = r'snippet: (.*?),\s*title: (.*?),\s*link: (https?://\S+)'
matches = re.findall(pattern, output, re.DOTALL)

for snippet, title, link in matches:
    print(f'Snippet: {snippet.strip()}')
    print(f'Title: {title.strip()}')
    print(f'Link: {link.strip()}')
    print('-' * 50)
# Out:
# Snippet: Hamburg ([ˈhambʊʁk] ; regiolektal auch [ˈhambʊɪ̯ç] , dialektal [ˈhambɔʁχ]), amtlich Freie und Hansestadt Hamburg (niederdeutsch Friee un Hansestadt Hamborg, Ländercode HH), ist als Stadtstaat ein Land der Bundesrepublik Deutschland.
# Title: Hamburg - Wikipedia
# Link: https://de.wikipedia.org/wiki/Hamburg,
# --------------------------------------------------
# Snippet: In Hamburg wird am 2. März gewählt. Der Wahl-O-Mat der Bundeszentrale für politische Bildung fragt Positionen der Nutzer ab und vergleicht sie mit den Profilen der Parteien. 1,3 Millionen ...
# Title: Wahl-O-Mat zur Wahl in Hamburg: Welche Partei passt zu mir?
# Link: https://www.zdf.de/nachrichten/politik/deutschland/wahlomat-hamburg-buergerschaftswahl-2025-100.html,
# --------------------------------------------------
# Snippet: Von der Elbphilharmonie über die Reeperbahn bis zum Miniatur Wunderland: Die besten Hamburg-Sehenswürdigkeiten 2024 mit Karte.
# Title: Top 12 Sehenswürdigkeiten in Hamburg 2025: Karte und Geheimtipps - ADAC
# Link: https://www.adac.de/reise-freizeit/reiseplanung/inspirationen/deutschland/hamburg-sehenswuerdigkeiten/,
# --------------------------------------------------
# Snippet: Hamburg Geheimtipps für alle, die Hamburg wie ein Einheimischer entdecken möchten. Jede Menge coole Spots in allen Ecken der Hansestadt.
# Title: 33 Hamburg Geheimtipps, die nur Einheimische kennen - Travel-Du.de
# Link: https://travel-du.de/14535/hamburg-geheimtipps/
# --------------------------------------------------

# %% [markdown]
# ### Wikipedia

# %%
pip install -q wikipedia
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

# %%
api_wrapper = WikipediaAPIWrapper(top_k_results=1, doc_content_chars_max=10000)
wiki = WikipediaQueryRun(api_wrapper=api_wrapper)
wiki.invoke({'query': 'DeepSeek R1'})
# Out:
# 'Page: DeepSeek\nSummary: DeepSeek (Chinese: 深度求索; pinyin: Shēndù Qiúsuǒ) is a Chinese artificial intelligence company that develops open-source large language models (LLMs). Based in Hangzhou, Zhejiang, it is owned and funded by Chinese hedge fund High-Flyer, whose co-founder, Liang Wenfeng, established the company in 2023 and serves as its CEO. \nThe DeepSeek-R1 model provides responses comparable to other contemporary LLMs, such as OpenAI\'s GPT-4o and o1. It is trained at a significantly lower cost—stated at US$6 million compared to $100 million for OpenAI\'s GPT-4 in 2023—and requires a tenth of the computing power of a comparable LLM. DeepSeek\'s A.I. models were developed amid United States sanctions on India and China for Nvidia chips, which were intended to restrict the ability of the two countries to develop advanced A.I. systems. \nOn 10 January 2025, DeepSeek released its first free chatbot app, based on the DeepSeek-R1 model, for iOS and Android; by 27 January, DeepSeek-R1 had surpassed ChatGPT as the most-downloaded free app on the iOS App Store in the United States, causing Nvidia\'s share price to drop by 18%. DeepSeek\'s success against larger and more established rivals has been described as "upending AI", constituting "the first shot at what is emerging as a global AI space race", and ushering in "a new era of A.I. brinkmanship".\nDeepSeek makes its generative artificial intelligence algorithms, models, and training details open-source, allowing its code to be freely available for use, modification, viewing, and designing documents for building purposes. The company reportedly vigorously recruits young A.I. researchers from top Chinese universities, and hires from outside the computer science field to diversify its models\' knowledge and abilities.'

# %%
output = wiki.invoke('Google Gemini 2.0')

# %%
print(output)
# Out:
# Page: Gemini (language model)
# Summary: Gemini (formerly known as Bard) is a family of multimodal large language models developed by Google DeepMind, serving as the successor to LaMDA and PaLM 2. Comprising Gemini Ultra, Gemini Pro, Gemini Flash, and Gemini Nano, it was announced on December 6, 2023, positioned as a competitor to OpenAI's GPT-4. It powers the chatbot of the same name.

# %% [markdown]
# ## Creating a ReAct Agent

# %%
pip install langchainhub -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
from langchain_core.prompts import PromptTemplate
from langchain_classic import hub
from langchain_classic.agents import Tool, AgentExecutor, initialize_agent, create_react_agent
from langchain_classic.tools import DuckDuckGoSearchRun, WikipediaQueryRun
from langchain_classic.utilities import WikipediaAPIWrapper
from langchain_experimental.tools.python.tool import PythonREPLTool
from langchain_openai import ChatOpenAI

# Initialize the ChatOpenAI model
llm = ChatOpenAI(model_name='gpt-4o-mini', temperature=0)

# Define a template for answering questions
template = '''
Answer the following questions in SPANISH as best you can.
Questions: {q}
'''

# Create a PromptTemplate object from the template
prompt_template = PromptTemplate.from_template(template)

# Pull the react prompt from the hub
prompt = hub.pull('hwchase17/react')

# displaying information about the react prompt
print(type(prompt))
print(prompt.input_variables)
print(prompt.template)

# Create tools for the agent

# 1. Python REPL Tool (for executing Python code)
python_repl = PythonREPLTool()
python_repl_tool = Tool(
    name='Python REPL',
    func=python_repl.run,
    description='Useful when you need to use Python to answer a question. You should input Python code.'
)

# 2. Wikipedia Tool (for searching Wikipedia)
api_wrapper = WikipediaAPIWrapper()
wikipedia = WikipediaQueryRun(api_wrapper=api_wrapper)
wikipedia_tool = Tool(
    name='Wikipedia',
    func=wikipedia.run,
    description='Useful for when you need to look up a topic, country, or person on Wikipedia.'
)

# 3. DuckDuckGo Search Tool (for general web searches)
search = DuckDuckGoSearchRun()
duckduckgo_tool = Tool(
    name='DuckDuckGo Search',
    func=search.run,
    description='Useful for when you need to perform an internet search to find information that another tool can\'t provide.'
)

# Combine the tools into a list
tools = [python_repl_tool, wikipedia_tool, duckduckgo_tool]

# Create a react agent with the ChatOpenAI model, tools, and prompt
agent = create_react_agent(llm, tools, prompt)

# Initialize the AgentExecutor
agent_executor = AgentExecutor(
    agent=agent,
    tools=tools,
    verbose=True,
    handle_parsing_errors=True,
    max_iterations=10
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\Documents\Udemy\Gen AI And Python\Python_GenAI_Bootcamp\.venv\Lib\site-packages\langsmith\utils.py:160, in raise_for_status_with_text(response)
#     159 try:
# --> 160     response.raise_for_status()
#     161 except requests.HTTPError as e:
#
# File ~\Documents\Udemy\Gen AI And Python\Python_GenAI_Bootcamp\.venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.smith.langchain.com/commits/hwchase17/react/latest
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# File ~\Documents\Udemy\Gen AI And Python\Python_GenAI_Bootcamp\.venv\Lib\site-packages\langsmith\client.py:1339, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#    1333     response = self.session.request(
#    1334         method,
#    1335         _construct_url(self.api_url, pathname),
#    1336         stream=False,
#    1337         **request_kwargs,
#    1338     )
# -> 1339 ls_utils.raise_for_status_with_text(response)
#    1340 return response
#
# File ~\Documents\Udemy\Gen AI And Python\Python_GenAI_Bootcamp\.venv\Lib\site-packages\langsmith\utils.py:162, in raise_for_status_with_text(response)
#     161 except requests.HTTPError as e:
# --> 162     raise requests.HTTPError(str(e), response.text) from e  # type: ignore[call-arg]
#     163 except httpx.HTTPStatusError as e:
#
# HTTPError: [Errno 403 Client Error: Forbidden for url: https://api.smith.langchain.com/commits/hwchase17/react/latest] {"error":"Forbidden"}
#
#
# During handling of the above exception, another exception occurred:
#
# LangSmithError                            Traceback (most recent call last)
# Cell In[11], line 22
#      19 prompt_template = PromptTemplate.from_template(template)
#      21 # Pull the react prompt from the hub
# ---> 22 prompt = hub.pull('hwchase17/react')
#      24 # displaying information about the react prompt
#      25 print(type(prompt))
#
# File ~\Documents\Udemy\Gen AI And Python\Python_GenAI_Bootcamp\.venv\Lib\site-packages\langchain_classic\hub.py:136, in pull(owner_repo_commit, include_model, api_url, api_key)
#     134 # Then it's langsmith
#     135 if hasattr(client, "pull_prompt"):
# --> 136     return client.pull_prompt(owner_repo_commit, include_model=include_model)
#     138 # Then it's langchainhub
#     139 if hasattr(client, "pull_repo"):
#     140     # >= 0.1.15
#
# File ~\Documents\Udemy\Gen AI And Python\Python_GenAI_Bootcamp\.venv\Lib\site-packages\langsmith\client.py:8634, in Client.pull_prompt(self, prompt_identifier, include_model, secrets, secrets_from_env, skip_cache)
#    8585 def pull_prompt(
#    8586     self,
#    8587     prompt_identifier: str,
#    (...)   8592     skip_cache: bool = False,
#    8593 ) -> Any:
#    8594     """Pull a prompt and return it as a LangChain `PromptTemplate`.
#    8595
#    8596     This method requires [`langchain-core`](https://pypi.org/project/langchain-core).
#    (...)   8632         langsmith package) depends on.
#    8633     """
# -> 8634     prompt_object = self.pull_prompt_commit(
#    8635         prompt_identifier, include_model=include_model, skip_cache=skip_cache
#    8636     )
#    8637     return _process_prompt_manifest(
#    8638         prompt_object,
#    8639         include_model=include_model,
#    8640         secrets=secrets,
#    8641         secrets_from_env=secrets_from_env,
#    8642     )
#
# File ~\Documents\Udemy\Gen AI And Python\Python_GenAI_Bootcamp\.venv\Lib\site-packages\langsmith\client.py:8519, in Client.pull_prompt_commit(self, prompt_identifier, include_model, skip_cache)
#    8516         return cached
#    8518 # Cache miss or cache skipped - fetch from API
# -> 8519 result = refresh_func()
#    8521 # Store in cache (background thread will handle refresh when stale)
#    8522 if not skip_cache and self._cache is not None:
#
# File ~\Documents\Udemy\Gen AI And Python\Python_GenAI_Bootcamp\.venv\Lib\site-packages\langsmith\client.py:8475, in Client._fetch_prompt_from_api(self, prompt_identifier, include_model)
#    8463 """Fetch a prompt directly from the API (no cache).
#    8464
#    8465 Args:
#    (...)   8470     The fetched PromptCommit.
#    8471 """
#    8472 owner, prompt_name, commit_hash = ls_utils.parse_prompt_identifier(
#    8473     prompt_identifier
#    8474 )
# -> 8475 response = self.request_with_retries(
#    8476     "GET",
#    8477     (
#    8478         f"/commits/{owner}/{prompt_name}/{commit_hash}"
#    8479         f"{'?include_model=true' if include_model else ''}"
#    8480     ),
#    8481 )
#    8482 return ls_schemas.PromptCommit(
#    8483     **{"owner": owner, "repo": prompt_name, **response.json()}
#    8484 )
#
# File ~\Documents\Udemy\Gen AI And Python\Python_GenAI_Bootcamp\.venv\Lib\site-packages\langsmith\client.py:1399, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#    1397     except (ValueError, KeyError):
#    1398         pass
# -> 1399     raise ls_utils.LangSmithError(
#    1400         f"Failed to {method} {pathname} in LangSmith"
#    1401         f" API. {repr(e)}"
#    1402     )
#    1403 else:
#    1404     raise ls_utils.LangSmithError(
#    1405         f"Failed to {method} {pathname} in LangSmith"
#    1406         f" API. {repr(e)}"
#    1407     )
#
# LangSmithError: Failed to GET /commits/hwchase17/react/latest in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/commits/hwchase17/react/latest', '{"error":"Forbidden"}\n')

# %%
# question = 'Generate the first 20 numbers in the Fibonacci series.'
# question = 'Who is the current prime minister of the UK?'
question = 'Tell me about Napoleon Bonaparte early life'
output = agent_executor.invoke({
    'input': prompt_template.format(q=question)
})
# Out:
# Error in StdOutCallbackHandler.on_chain_start callback: AttributeError("'NoneType' object has no attribute 'get'")
# Para responder a la pregunta sobre la vida temprana de Napoleón Bonaparte, necesito buscar información sobre su infancia y juventud.
#
# Action: Wikipedia
# Action Input: "Napoleón Bonaparte vida temprana"
# No good Wikipedia Search Result was foundParece que no encontré información relevante en Wikipedia. Intentaré buscar en DuckDuckGo para obtener detalles sobre la vida temprana de Napoleón Bonaparte.
#
# Action: DuckDuckGo Search
# Action Input: "Napoleón Bonaparte early life"
# Napoleon I, also called Napoléon Bonaparte, was a French military general and statesman. Napoleon played a key role in the French Revolution (1789-99), served as first consul of France (1799-1804), and was the first emperor of France (1804-14/15). Early Life and Education. Napoleon Bonaparte, born Napoleone Buonaparte on August 15, 1769, in Ajaccio, Corsica, was the second surviving child of Carlo Buonaparte, a lawyer, and Letizia Ramolino. He grew up in a family with a total of seven siblings, experiencing the tensions of Corsican resistance to French occupation. ... Napoleon Bonaparte, born in Corsica in 1769, rose through the ranks of the French army and became a wildly ambitious military leader known for his speed and cunning on the battlefield. Napoleon crowned himself Emperor of France in 1804 after a series of political maneuvers, implementing reforms that brought financial security and stability to ... Early Life and Rise to Power. Napoleon Bonaparte, a name that echoes through history, was a man of many talents and ambitions. His journey from a small island to the throne of France is filled with fascinating details. Corsican Roots: Born on August 15, 1769, in Ajaccio, Corsica, Napoleon was the second of eight children in his family. His ... The Battle of Waterloo. The Battle of Waterloo stands as a defining moment in history, forever etched into the annals of European warfare. It was during this critical encounter that Napoleon Bonaparte, the renowned French Emperor, faced his ultimate defeat, marking the end of his reign and reshaping the political landscape of Europe.. The Battle of Waterloo took place on June 18, 1815, near ...Ahora tengo suficiente información sobre la vida temprana de Napoleón Bonaparte.
#
# Final Answer: Napoleón Bonaparte, nacido como Napoleone Buonaparte el 15 de agosto de 1769 en Ajaccio, Córcega, fue el segundo hijo sobreviviente de Carlo Buonaparte, un abogado, y Letizia Ramolino. Creció en una familia con un total de siete hermanos, experimentando las tensiones de la resistencia corsa a la ocupación francesa. Desde joven, mostró un gran interés por la educación y la estrategia militar, lo que lo llevó a ascender rápidamente en las filas del ejército francés. Su infancia estuvo marcada por la influencia de su entorno corsa y las dificultades políticas de la época.
#
# > Finished chain.

# %%
print(output['input'])
# Out:
# Answer the following questions in SPANISH as best you can.
# Questions: Tell me about Napoleon Bonaparte early life

# %%
output['output']
# Out:
# 'Napoleón Bonaparte, nacido como Napoleone Buonaparte el 15 de agosto de 1769 en Ajaccio, Córcega, fue el segundo hijo sobreviviente de Carlo Buonaparte, un abogado, y Letizia Ramolino. Creció en una familia con un total de siete hermanos, experimentando las tensiones de la resistencia corsa a la ocupación francesa. Desde joven, mostró un gran interés por la educación y la estrategia militar, lo que lo llevó a ascender rápidamente en las filas del ejército francés. Su infancia estuvo marcada por la influencia de su entorno corsa y las dificultades políticas de la época.'
