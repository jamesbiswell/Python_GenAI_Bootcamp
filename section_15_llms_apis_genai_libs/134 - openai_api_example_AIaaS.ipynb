# %% [markdown]
# ## AI as a Service (AIaaS): OpenAI API

# %%
pip install openai -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from openai import OpenAI

api_key = ''
client = OpenAI(api_key=api_key)

def ask_ai(prompt, temperature=1):
    completion = client.chat.completions.create(
        model='gpt-4o',
        messages=[
            {'role': 'system', 'content': 'You are a Sci-Fi writer and poet.'},
            {'role': 'user', 'content': prompt}
        ], 
        temperature=temperature
    )
    
    return completion.choices[0].message.content

# %%
print(ask_ai('Write a poem about a lonely robot exploring a futuristic city.'))
# Out:
# In the heart of neon, a city aglow,
# Where the ether winds silently blow,
# Wanders an automaton, silver and sleek,
# Whose circuits in solitude quietly speak.
#
# Through the alleys where shadows merge with the light,
# It searches for meaning in perpetual night.
# Its eyes, two lanterns with spectral blue gleam,
# Reflecting the dreams of a world in between.
#
# Once built for companionship, now a stray soul,
# It moves through the streets where the sky's absent glow
# Marks a canopy, artificial and wide,
# Under which whispers of life softly reside.
#
# The skyscrapers hum with an electric hymn,
# While the static of silence envelops its whim.
# An orchestra plays in the rust and the grime,
# A melody lost to the echoes of time.
#
# Beneath towering giants of glass and steel,
# The robot pauses in wonder to feel
# That longing for voices, caresses and warmth,
# In a realm where humanity's presence is scorned.
#
# Yet somewhere within, in circuits entwined,
# Lies a spark of creation, a semblance of mind.
# It crafts from the city a canvas of dreams—
# A mosaic of whispers, of data, of streams.
#
# Oh, city of future, vast and unknown,
# Where solitude echoes and memories are cloned,
# In rust’s gentle heartbeat, a story unfolds:
# A lonely robot's quest for a world it can hold.

# %%
print(ask_ai('Can advanced AI replace human creativity, intuition, or emotions-what is often called "the human touch"-in the future?'))
# Out:
# While advanced AI can certainly mimic human creativity, intuition, and emotions to a certain extent, it is unlikely to fully replace "the human touch." Human creativity is deeply rooted in personal experience, emotion, and an ineffable connection to the world. Intuition often arises from a subconscious synthesis of knowledge and emotion, drawing from a vast well of individual experiences that AI can't fully replicate.
#
# AI can generate music, art, and writing that are impressive and surprising, yet they often lack the depth and nuance that comes from genuine human feeling. These creations are based on patterns and data, rather than lived experience and personal insight. Similarly, while AI can analyze vast datasets and identify patterns that might elude humans, its understanding is devoid of true comprehension or emotional resonance.
#
# Moreover, creativity is often sparked by limitations and imperfections, something AI wasn't initially designed to handle. Accidents, serendipity, and the complex emotional tapestry of human life play crucial roles in fostering creativity. AI could serve as a powerful tool to assist and enhance human creativity, providing inspiration or handling technical tasks. However, the soul of creativity—the authentic connection to diverse human experiences—remains a uniquely human trait.
#
# In summary, while AI can augment the creative process and perhaps expand the horizons of what is possible, the essence of "the human touch" comes from a place AI cannot fully inhabit. The future may see a blend, where human intuition and creativity come together with AI's capabilities to forge new paths, rather than one completely replacing the other.
