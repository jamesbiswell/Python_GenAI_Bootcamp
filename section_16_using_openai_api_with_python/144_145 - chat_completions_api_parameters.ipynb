# %% [markdown]
# ### Chat Completions API Parameters

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
# openai.api_key = os.getenv('OPENAI_API_KEY')
# Out:
# True

# %%
import os
from openai import OpenAI

client = OpenAI()

response = client.chat.completions.create(
    model='gpt-4o-mini',
    messages= [
        {'role': 'developer', 'content': 'You are a helpful assistant.'},
        {'role': 'user', 'content': 'Write a short article about coffee.'}
    ],
    temperature=1,
#     seed=1234
#     top_p=0.1,
#     max_tokens=10
#     n=2
#     stop=[';', '.', '\n']
    frequency_penalty=0,  # between  -2 and 2, default 0
    presence_penalty=0 # [-2, +2]
)

print(response.choices[0].message.content)
# Out:
# ### The Rich World of Coffee: A Global Journey in Every Sip
#
# Coffee, one of the world's most beloved beverages, has a rich history and a profound cultural significance that transcends borders. Originating from the coffee forests of Ethiopia, the story of coffee has evolved over centuries, transforming into a global phenomenon that fuels the daily lives of millions.
#
# #### The Origins of Coffee
#
# Legend has it that coffee was discovered in the 9th century by a goat herder named Kaldi, who noticed that his goats became more energetic after eating the red berries from a certain shrub. This discovery led to the cultivation of coffee plants, with Yemen becoming the first region to brew coffee as a drink in the 15th century. From there, coffee spread to Persia, Egypt, and the Ottoman Empire, quickly gaining popularity.
#
# By the 17th century, coffee had made its way to Europe, where it became a symbol of sophistication and intellectualism. Coffeehouses emerged as centers for conversation, political discourse, and artistic inspiration, with notable figures like Voltaire and Rousseau frequenting these establishments.
#
# #### Coffee Cultivation and Varieties
#
# Today, coffee is grown in over 70 countries, primarily in the "Coffee Belt," a region between the Tropics of Cancer and Capricorn. The two most commercially important species are Coffea arabica (Arabica) and Coffea canephora (Robusta). Arabica is known for its smooth flavor and aroma, while Robusta is often favored for its higher caffeine content and bold taste.
#
# Coffee cultivation is a labor-intensive process. It involves planting, nurturing, harvesting, and processing the beans, which are then roasted to develop various flavor profiles. The roasting process transforms the green beans into the aromatic brown ones we are familiar with, and it significantly influences the final taste.
#
# #### The Art of Brewing
#
# Brewing coffee is an art form in itself, with various methods available to enthusiasts. From the classic French press to espresso machines, pour-over, and cold brew, each method brings out distinct flavors and aromas. Coffee aficionados often explore the nuances of brewing times, water temperatures, and grind sizes to achieve the perfect cup.
#
# Coffee has also inspired a culture of specialty drinks, ranging from lattes and cappuccinos to more avant-garde combinations with flavors like pumpkin spice and lavender. The emergence of third-wave coffee has brought a focus on sustainable sourcing and artisanal roasting, elevating coffee from a mere commodity to a craft experience.
#
# #### The Global Impact of Coffee
#
# While coffee is a beloved beverage, it also plays a significant role in the global economy. Millions of people depend on coffee cultivation for their livelihoods, with smallholder farmers making up a large portion of coffee producers. However, the industry faces challenges, including climate change, which poses a threat to coffee crops and the livelihoods of those who grow them. Efforts to promote sustainable practices and fair trade are critical in ensuring the long-term viability of coffee production.
#
# #### Conclusion
#
# From its intriguing origins to its current status as a global staple, coffee continues to captivate individuals around the world. Whether enjoyed in solitude or with friends, a cup of coffee offers a moment of connection—and a taste of the rich stories and traditions that fuel its journey from bean to brew. So, the next time you savor your favorite coffee, take a moment to appreciate not just the flavor, but the centuries of culture and community that it represents.
