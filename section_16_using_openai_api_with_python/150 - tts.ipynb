# %% [markdown]
# ## Text to Speech (TTS) API

# %%
# loading the OpenAI API key for authentication
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
# text = 'Viitorul este o carte deschisă, plină de capitole încă nescrise,\
# așteptând strălucirea minților noastre să picteze poveștile lor.'

text = 'In the future, we may be able to travel to other galaxies using wormholes or warp drives.'

# %%
# https://openai.com/api/pricing/
cost = len(text)/1000 * 0.15  # cost in cents
cost
# Out:
# 0.013349999999999999

# %%
from openai import OpenAI
client = OpenAI()

response = client.audio.speech.create(
     model="tts-1", 
     voice="alloy",  
     input=text
)

# 1. 
response.stream_to_file('files/tts.mp3')  
# or if you get a DeprecationWarning use this instead:
# 2.
with open('files/tts-1.mp3', 'wb') as f:
    f.write(response.content)
# Out:
# /tmp/ipykernel_31391/313157670.py:11: DeprecationWarning: Due to a bug, this method doesn't actually stream the response content, `.with_streaming_response.method()` should be used instead
#   response.stream_to_file('files/tts.mp3')

# %%
import IPython
IPython.display.Audio('tts-1.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
