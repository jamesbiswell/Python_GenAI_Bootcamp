# %% [markdown]
# ## Diving into Gemini API with Python
# ### Building Chat Conversations

# %%
# importing the libraries.
import google.generativeai as genai
import os
from dotenv import load_dotenv, find_dotenv


# configuring the API key.
genai.configure(api_key=os.environ.get('GOOGLE_API_KEY'))

# %%
# loading the API key from .env to authenticate
load_dotenv(find_dotenv(), override=True)
# os.environ.get('GOOGLE_API_KEY')
# Out:
# True

# %%
model = genai.GenerativeModel('gemini-2.5-flash')

# creating a ChatSession object
# use the model.start_chat() method instead of model.generate_content() to start a multi-turn conversation
chat = model.start_chat(history=[])  
chat
# Out:
# ChatSession(
#     model=genai.GenerativeModel(
#         model_name='models/gemini-2.5-flash',
#         generation_config={},
#         safety_settings={},
#         tools=None,
#         system_instruction=None,
#         cached_content=None
#     ),
#     history=[]
# )

# %%
response = chat.send_message('In one paragraph, explain how the Internet works to a beginner.')

# %%
# displaying the chat history
chat.history
# Out:
# [parts {
#    text: "In one paragraph, explain how the Internet works to a beginner."
#  }
#  role: "user",
#  parts {
#    text: "The Internet is a vast, global network of interconnected computers and other devices, working like an enormous postal service for digital information. When you want to visit a website or send an email, your device (a \"client\") sends a request, which is broken down into tiny digital \"packets.\" These packets travel across a complex web of physical cables (like fiber optics) and wireless signals, guided by specialized devices called \"routers\" that direct traffic. Eventually, they reach their destination: a \"server\" computer that stores the website\'s data or your friend\'s email. The server then sends the requested information back in the same packet form, through the same network of routers, directly to your device, which reassembles it so you can see the webpage, stream a video, or receive your message."
#  }
#  role: "model"]

# %%
# displaying the first user's question
chat.history[0]
# Out:
# parts {
#   text: "In one paragraph, explain how the Internet works to a beginner."
# }
# role: "user"

# %%
# displaying the model's response
chat.history[1]
# Out:
# parts {
#   text: "The Internet is a vast, global network of interconnected computers and other devices, working like an enormous postal service for digital information. When you want to visit a website or send an email, your device (a \"client\") sends a request, which is broken down into tiny digital \"packets.\" These packets travel across a complex web of physical cables (like fiber optics) and wireless signals, guided by specialized devices called \"routers\" that direct traffic. Eventually, they reach their destination: a \"server\" computer that stores the website\'s data or your friend\'s email. The server then sends the requested information back in the same packet form, through the same network of routers, directly to your device, which reassembles it so you can see the webpage, stream a video, or receive your message."
# }
# role: "model"

# %%
chat.history[1].parts[0].text
# Out:
# 'The Internet is a vast, global network of interconnected computers and other devices, working like an enormous postal service for digital information. When you want to visit a website or send an email, your device (a "client") sends a request, which is broken down into tiny digital "packets." These packets travel across a complex web of physical cables (like fiber optics) and wireless signals, guided by specialized devices called "routers" that direct traffic. Eventually, they reach their destination: a "server" computer that stores the website\'s data or your friend\'s email. The server then sends the requested information back in the same packet form, through the same network of routers, directly to your device, which reassembles it so you can see the webpage, stream a video, or receive your message.'

# %%
# sending another prompt for the same conversation
response = chat.send_message('Okay, how about a more detailed explanation about the IP addresses?')

# %%
chat.history
# Out:
# [parts {
#    text: "In one paragraph, explain how the Internet works to a beginner."
#  }
#  role: "user",
#  parts {
#    text: "The Internet is a vast, global network of interconnected computers and other devices, working like an enormous postal service for digital information. When you want to visit a website or send an email, your device (a \"client\") sends a request, which is broken down into tiny digital \"packets.\" These packets travel across a complex web of physical cables (like fiber optics) and wireless signals, guided by specialized devices called \"routers\" that direct traffic. Eventually, they reach their destination: a \"server\" computer that stores the website\'s data or your friend\'s email. The server then sends the requested information back in the same packet form, through the same network of routers, directly to your device, which reassembles it so you can see the webpage, stream a video, or receive your message."
#  }
#  role: "model",
#  parts {
#    text: "Okay, how about a more detailed explanation about the IP addresses?"
#  }
#  role: "user",
#  parts {
#    text: "IP addresses, short for Internet Protocol addresses, are fundamental to how the Internet operates, acting much like unique street addresses for every device connected to a network. Each IP address is a unique numerical label assigned to every device participating in a computer network that uses the Internet Protocol for communication.\n\nThink of it this way: when you send a physical letter, you need a recipient\'s street address, city, and zip code for it to reach the correct mailbox. Similarly, when your computer sends data (like requesting a webpage) across the Internet, it\'s broken into tiny \"packets,\" and each packet needs a destination IP address so routers know exactly where to send it. Your own device also has an IP address so that the web server knows where to send the requested webpage back.\n\nThere are two main types of IP addresses you\'ll commonly encounter:\n\n1.  **IPv4 (Internet Protocol version 4):** This is the older, more common format, appearing as four sets of numbers separated by dots (e.g., `192.168.1.1` or `203.0.113.45`). Each number in a set can range from 0 to 255. An IPv4 address is logically divided into two parts: a **network portion** (identifying the specific network the device is on, like a neighborhood) and a **host portion** (identifying the specific device within that network, like a house number). Routers use the network portion to direct traffic between different networks.\n\n2.  **IPv6 (Internet Protocol version 6):** As the Internet grew, the world started running out of unique IPv4 addresses. IPv6 was created to solve this, offering a vastly larger address space. It looks much different, using alphanumeric characters and colons (e.g., `2001:0db8:85a3:0000:0000:8a2e:0370:7334`). While more complex visually, it offers enhanced efficiency and features.\n\nFurthermore, IP addresses can be categorized as **public** or **private**:\n\n*   **Public IP addresses** are unique on the global Internet. Your home router, for instance, has one public IP address assigned by your Internet Service Provider (ISP). This is the address the outside world sees when you connect to a website.\n*   **Private IP addresses** are used *within* a local network (like your home or office). Devices on your home network (your laptop, phone, smart TV) will each have a private IP address (often in ranges like `192.168.x.x`). These addresses are not unique globally and cannot be directly accessed from the Internet. Your router uses a process called **Network Address Translation (NAT)** to allow multiple devices with private IPs to share a single public IP address when communicating with the outside world, acting as a translator so return traffic knows which internal device to go to.\n\nIn essence, IP addresses are the digital coordinates that allow every device on the Internet to find and communicate with each other, ensuring that data packets are delivered to their correct destination, even if you just type in a human-friendly domain name like \"google.com\" (which is then translated into an IP address by a system called DNS)."
#  }
#  role: "model"]

# %%
# sending another prompt for the same conversation
response = chat.send_message('What have I asked you so far')
chat.history
# Out:
# [parts {
#    text: "In one paragraph, explain how the Internet works to a beginner."
#  }
#  role: "user",
#  parts {
#    text: "The Internet is a vast, global network of interconnected computers and other devices, working like an enormous postal service for digital information. When you want to visit a website or send an email, your device (a \"client\") sends a request, which is broken down into tiny digital \"packets.\" These packets travel across a complex web of physical cables (like fiber optics) and wireless signals, guided by specialized devices called \"routers\" that direct traffic. Eventually, they reach their destination: a \"server\" computer that stores the website\'s data or your friend\'s email. The server then sends the requested information back in the same packet form, through the same network of routers, directly to your device, which reassembles it so you can see the webpage, stream a video, or receive your message."
#  }
#  role: "model",
#  parts {
#    text: "Okay, how about a more detailed explanation about the IP addresses?"
#  }
#  role: "user",
#  parts {
#    text: "IP addresses, short for Internet Protocol addresses, are fundamental to how the Internet operates, acting much like unique street addresses for every device connected to a network. Each IP address is a unique numerical label assigned to every device participating in a computer network that uses the Internet Protocol for communication.\n\nThink of it this way: when you send a physical letter, you need a recipient\'s street address, city, and zip code for it to reach the correct mailbox. Similarly, when your computer sends data (like requesting a webpage) across the Internet, it\'s broken into tiny \"packets,\" and each packet needs a destination IP address so routers know exactly where to send it. Your own device also has an IP address so that the web server knows where to send the requested webpage back.\n\nThere are two main types of IP addresses you\'ll commonly encounter:\n\n1.  **IPv4 (Internet Protocol version 4):** This is the older, more common format, appearing as four sets of numbers separated by dots (e.g., `192.168.1.1` or `203.0.113.45`). Each number in a set can range from 0 to 255. An IPv4 address is logically divided into two parts: a **network portion** (identifying the specific network the device is on, like a neighborhood) and a **host portion** (identifying the specific device within that network, like a house number). Routers use the network portion to direct traffic between different networks.\n\n2.  **IPv6 (Internet Protocol version 6):** As the Internet grew, the world started running out of unique IPv4 addresses. IPv6 was created to solve this, offering a vastly larger address space. It looks much different, using alphanumeric characters and colons (e.g., `2001:0db8:85a3:0000:0000:8a2e:0370:7334`). While more complex visually, it offers enhanced efficiency and features.\n\nFurthermore, IP addresses can be categorized as **public** or **private**:\n\n*   **Public IP addresses** are unique on the global Internet. Your home router, for instance, has one public IP address assigned by your Internet Service Provider (ISP). This is the address the outside world sees when you connect to a website.\n*   **Private IP addresses** are used *within* a local network (like your home or office). Devices on your home network (your laptop, phone, smart TV) will each have a private IP address (often in ranges like `192.168.x.x`). These addresses are not unique globally and cannot be directly accessed from the Internet. Your router uses a process called **Network Address Translation (NAT)** to allow multiple devices with private IPs to share a single public IP address when communicating with the outside world, acting as a translator so return traffic knows which internal device to go to.\n\nIn essence, IP addresses are the digital coordinates that allow every device on the Internet to find and communicate with each other, ensuring that data packets are delivered to their correct destination, even if you just type in a human-friendly domain name like \"google.com\" (which is then translated into an IP address by a system called DNS)."
#  }
#  role: "model",
#  parts {
#    text: "What have I asked you so far"
#  }
#  role: "user",
#  parts {
#    text: "You\'ve asked me two questions so far:\n\n1.  First, you asked for a one-paragraph explanation of **how the Internet works to a beginner.**\n2.  Second, you requested a more detailed explanation specifically about **IP addresses.**"
#  }
#  role: "model"]

# %%
# displaying the last answer
print(chat.history[-1].parts[0].text)
# Out:
# You've asked me two questions so far:
#
# 1.  First, you asked for a one-paragraph explanation of **how the Internet works to a beginner.**
# 2.  Second, you requested a more detailed explanation specifically about **IP addresses.**

# %%
# displaying the entire conversation using a for loop
for item in chat.history:
    print(f'{item.role.capitalize()}: {item.parts[0].text}')
    print('-' * 100)
# Out:
# User: In one paragraph, explain how the Internet works to a beginner.
# ----------------------------------------------------------------------------------------------------
# Model: The Internet is a vast, global network of interconnected computers and other devices, working like an enormous postal service for digital information. When you want to visit a website or send an email, your device (a "client") sends a request, which is broken down into tiny digital "packets." These packets travel across a complex web of physical cables (like fiber optics) and wireless signals, guided by specialized devices called "routers" that direct traffic. Eventually, they reach their destination: a "server" computer that stores the website's data or your friend's email. The server then sends the requested information back in the same packet form, through the same network of routers, directly to your device, which reassembles it so you can see the webpage, stream a video, or receive your message.
# ----------------------------------------------------------------------------------------------------
# User: Okay, how about a more detailed explanation about the IP addresses?
# ----------------------------------------------------------------------------------------------------
# Model: IP addresses, short for Internet Protocol addresses, are fundamental to how the Internet operates, acting much like unique street addresses for every device connected to a network. Each IP address is a unique numerical label assigned to every device participating in a computer network that uses the Internet Protocol for communication.
#
# Think of it this way: when you send a physical letter, you need a recipient's street address, city, and zip code for it to reach the correct mailbox. Similarly, when your computer sends data (like requesting a webpage) across the Internet, it's broken into tiny "packets," and each packet needs a destination IP address so routers know exactly where to send it. Your own device also has an IP address so that the web server knows where to send the requested webpage back.
#
# There are two main types of IP addresses you'll commonly encounter:
#
# 1.  **IPv4 (Internet Protocol version 4):** This is the older, more common format, appearing as four sets of numbers separated by dots (e.g., `192.168.1.1` or `203.0.113.45`). Each number in a set can range from 0 to 255. An IPv4 address is logically divided into two parts: a **network portion** (identifying the specific network the device is on, like a neighborhood) and a **host portion** (identifying the specific device within that network, like a house number). Routers use the network portion to direct traffic between different networks.
#
# 2.  **IPv6 (Internet Protocol version 6):** As the Internet grew, the world started running out of unique IPv4 addresses. IPv6 was created to solve this, offering a vastly larger address space. It looks much different, using alphanumeric characters and colons (e.g., `2001:0db8:85a3:0000:0000:8a2e:0370:7334`). While more complex visually, it offers enhanced efficiency and features.
#
# Furthermore, IP addresses can be categorized as **public** or **private**:
#
# *   **Public IP addresses** are unique on the global Internet. Your home router, for instance, has one public IP address assigned by your Internet Service Provider (ISP). This is the address the outside world sees when you connect to a website.
# *   **Private IP addresses** are used *within* a local network (like your home or office). Devices on your home network (your laptop, phone, smart TV) will each have a private IP address (often in ranges like `192.168.x.x`). These addresses are not unique globally and cannot be directly accessed from the Internet. Your router uses a process called **Network Address Translation (NAT)** to allow multiple devices with private IPs to share a single public IP address when communicating with the outside world, acting as a translator so return traffic knows which internal device to go to.
#
# In essence, IP addresses are the digital coordinates that allow every device on the Internet to find and communicate with each other, ensuring that data packets are delivered to their correct destination, even if you just type in a human-friendly domain name like "google.com" (which is then translated into an IP address by a system called DNS).
# ----------------------------------------------------------------------------------------------------
# User: What have I asked you so far
# ----------------------------------------------------------------------------------------------------
# Model: You've asked me two questions so far:
#
# 1.  First, you asked for a one-paragraph explanation of **how the Internet works to a beginner.**
# 2.  Second, you requested a more detailed explanation specifically about **IP addresses.**
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### While Loop for Multi-Turn Conversation

# %%
import time
model = genai.GenerativeModel('gemini-2.5-flash')
chat = model.start_chat(history=[])
while True:
    prompt = input('User: ')
    if prompt.lower() not in ['exit', 'quit', 'bye']:
        response = chat.send_message(prompt)
        print(f'{chat.history[-1].role.capitalize()}: {chat.history[-1].parts[0].text}')
        print('\n' + '*' * 100 + '\n')
    else:
        print('Quitting ...')
        time.sleep(2)
        print('Bye-bye!')
        break
# Out:
# Model: Hello! How can I help you today?
#
# ****************************************************************************************************
#
# Quitting ...
# Bye-bye!
