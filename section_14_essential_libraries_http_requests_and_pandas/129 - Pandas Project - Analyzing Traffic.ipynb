# %% [markdown]
# ## Pandas Project: Analyzing Website Traffic Data

# %%
import pandas as pd
df = pd.read_csv('website_traffic_data.csv')
df
# Out:
#       Source  SessionDuration
# 0    Organic             8.15
# 1    Organic            17.28
# 2     Direct             8.62
# 3       Paid            17.95
# 4       Paid            27.04
# ..       ...              ...
# 95  Referral            24.42
# 96  Referral             6.52
# 97      Paid             3.81
# 98    Direct            13.50
# 99      Paid            13.28
#
# [100 rows x 2 columns]

# %%
grouped_data = df.groupby('Source')
average_durations = grouped_data['SessionDuration'].mean()
average_durations
# Out:
# Source
# Direct      15.151364
# Organic     16.472609
# Paid        12.541667
# Referral    14.485333
# Social      17.070625
# Name: SessionDuration, dtype: float64
